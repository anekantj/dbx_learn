# %%
# %sql
use catalog databricks_catalog_101;
use schema adventures_works;

# %%
# %sql
select current_catalog(),current_schema()

# %%
# %sql
create  OR REPLACE table AW_CALENDAR as 
select * from 
read_files('/Volumes/databricks_catalog_101/adventures_works/raw_files/AdventureWorks_Calendar.csv',
format=>'csv');

SELECT * FROM aw_calendar;
