# %%
# %sql
use catalog databricks_catalog_101;
use schema adventures_works;

# %%
# %sql
select current_catalog(),current_schema()

# %%
# %sql
CREATE OR REPLACE TABLE aw_calendar
AS
SELECT *
FROM read_files(
  '/Volumes/databricks_catalog_101/adventures_works/raw_files/AdventureWorks_Calendar.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

# %%
# %sql
SELECT * FROM aw_calendar;

# %%
# %sql
create  or replace  table aw_customers as
SELECT * FROM read_files(
  '/Volumes/databricks_catalog_101/adventures_works/raw_files/AdventureWorks_Customers.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

# %%
# %sql
SELECT * FROM aw_customers;

# %%
# %sql
create  or replace  table AW_PRODUCT_CATEGORIES as
SELECT * FROM read_files(
  '/Volumes/databricks_catalog_101/adventures_works/raw_files/AdventureWorks_Product_Categories.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

SELECT * FROM aw_product_categories;

# %%
# %sql
create  or replace  table AW_PRODUCT_SUBCATEGORIES as
SELECT * FROM read_files(
  '/Volumes/databricks_catalog_101/adventures_works/raw_files/AdventureWorks_Product_Subcategories.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

SELECT * FROM aw_product_SUBcategories;

# %%
# %sql
create  or replace  table AW_PRODUCTS as
SELECT * FROM READ_FILES(
  '/Volumes/databricks_catalog_101/adventures_works/raw_files/AdventureWorks_Products.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);
    
    SELECT * FROM aw_products;

# %%
# %sql
create  or replace  table AW_RETURNS as
SELECT * FROM READ_FILES(
  '/Volumes/databricks_catalog_101/adventures_works/raw_files/AdventureWorks_Returns.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);
    
    SELECT * FROM AW_RETURNS;

# %%
# %sql
create  or replace  table AW_Territories as
SELECT * FROM READ_FILES(
  '/Volumes/databricks_catalog_101/adventures_works/raw_files/AdventureWorks_Territories.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);
    
    SELECT * FROM AW_Territories;
